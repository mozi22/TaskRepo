# %%
from pyspark import SparkContext
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, avg, month

# %% [markdown]
# ## Import Data

# %%
spark = SparkSession.builder \
     .master("local") \
     .appName("Group Task") \
     .getOrCreate()

sparkdf = spark.read.csv(
    "./yellow_taxi_2017-01.csv", header=True, sep=',',inferSchema =True
)

# %% [markdown]
# #### We need to take a look at how our data looks:

# %%
sparkdf.show()
# Out:
# +--------+--------------------+---------------------+---------------+-------------+----------+------------------+------------+------------+------------+-----------+-----+-------+----------+------------+---------------------+------------+
# |VendorID|tpep_pickup_datetime|tpep_dropoff_datetime|passenger_count|trip_distance|RatecodeID|store_and_fwd_flag|PULocationID|DOLocationID|payment_type|fare_amount|extra|mta_tax|tip_amount|tolls_amount|improvement_surcharge|total_amount|
# +--------+--------------------+---------------------+---------------+-------------+----------+------------------+------------+------------+------------+-----------+-----+-------+----------+------------+---------------------+------------+
# |       1| 2017-01-09 11:13:28|  2017-01-09 11:25:45|              1|          3.3|         1|                 N|         263|         161|           1|       12.5|  0.0|    0.5|       2.0|         0.0|                  0.3|        15.3|
# ...

# %% [markdown]
# ### Find the avg trip length of each taxi
#
# 1) Different taxis are considered to be represented by different VendorID
#
# 2) Grouping w.r.t pickup time.

# %%
sparkdf.groupby('VendorID',month('tpep_pickup_datetime')).agg(avg('trip_distance')).show()
# Out:
# +--------+---------------------------+------------------+
# |VendorID|month(tpep_pickup_datetime)|avg(trip_distance)|
# +--------+---------------------------+------------------+
# |       1|                          1| 2.732389963348606|
# |       2|                          1|2.8813791378078526|
# +--------+---------------------------+------------------+
